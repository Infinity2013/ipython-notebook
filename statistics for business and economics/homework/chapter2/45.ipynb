# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("../../data/2/SuperBowl.xlsx")
data.head()
# Out:
#    Super Bowl  Year       State        Winning Team  Points  \
# 0           1  1967  California   Green Bay Packers      35
# 1           2  1968     Florida   Green Bay Packers      33
# 2           3  1969     Florida       New York Jets      16
# 3           4  1970   Louisiana  Kansas City Chiefs      23
# 4           5  1971     Florida     Baltimore Colts      16
#
#           Losing Team  Points.1  Winning Margin
# 0  Kansas City Chiefs        10              25
# 1     Oakland Raiders        14              19
# 2     Baltimore Colts         7               9
# 3   Minnesota Vikings         7              16
# 4      Dallas Cowboys        13               3

# %%
data.describe()
# Out:
#        Super Bowl         Year     Points   Points.1  Winning Margin
# count   43.000000    43.000000  43.000000  43.000000       43.000000
# mean    22.000000  1988.000000  29.883721  15.325581       14.558140
# std     12.556539    12.556539  10.071670   6.556425       10.321735
# min      1.000000  1967.000000  14.000000   3.000000        1.000000
# 25%     11.500000  1977.500000  23.000000  10.000000        6.000000
# 50%     22.000000  1988.000000  28.000000  16.000000       13.000000
# 75%     32.500000  1998.500000  35.000000  19.500000       19.000000
# max     43.000000  2009.000000  55.000000  31.000000       45.000000

# %%
cityDis = pd.DataFrame(data['State'].value_counts().to_dict().items(), columns=['state', 'freq'])
cityDis
# Out:
#         state  freq
# 0     Georgia     2
# 1    Michigan     2
# 2     Florida    15
# 3   Minnesota     1
# 4     Arizona     2
# 5  California    11
# 6   Louisiana     8
# 7       Texas     2

# %%
plt.bar(np.arange(8), cityDis['freq'], 0.3)
plt.xticks(np.arange(8), cityDis['state'], rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x7f550130e710>,
# ...
#  <a list of 8 Text xticklabel objects>)
